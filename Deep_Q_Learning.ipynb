# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf

# %%
# !apt-get install swig cmake ffmpeg

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 269      |
# |    time_elapsed     | 917      |
# |    total_timesteps  | 247359   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 36839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 269      |
# |    time_elapsed     | 922      |
# |    total_timesteps  | 248147   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 37036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 268      |
# |    time_elapsed     | 928      |
# |    total_timesteps  | 249450   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 37362    |
# ----------------------------------
# Eval num_timesteps=250000, episode_reward=198.00 +/- 64.47
# Episode length: 2637.00 +/- 451.90
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.64e+03 |
# |    mean_reward      | 198      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 250000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 37499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 266      |
# |    time_elapsed     | 940      |
# |    total_timesteps  | 250210   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 37552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 265      |
# |    time_elapsed     | 944      |
# |    total_timesteps  | 251066   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 37766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 265      |
# |    time_elapsed     | 948      |
# |    total_timesteps  | 252038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 38009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 265      |
# |    time_elapsed     | 953      |
# |    total_timesteps  | 253056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 38263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 265      |
# |    time_elapsed     | 957      |
# |    total_timesteps  | 253944   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00953  |
# |    n_updates        | 38485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 265      |
# |    time_elapsed     | 959      |
# |    total_timesteps  | 254548   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 38636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 265      |
# |    time_elapsed     | 962      |
# |    total_timesteps  | 255418   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0188   |
# |    n_updates        | 38854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 265      |
# |    time_elapsed     | 966      |
# |    total_timesteps  | 256096   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00741  |
# |    n_updates        | 39023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 264      |
# |    time_elapsed     | 969      |
# |    total_timesteps  | 256720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.071    |
# |    n_updates        | 39179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 264      |
# |    time_elapsed     | 972      |
# |    total_timesteps  | 257445   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 39361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 264      |
# |    time_elapsed     | 976      |
# |    total_timesteps  | 258401   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00856  |
# |    n_updates        | 39600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 264      |
# |    time_elapsed     | 980      |
# |    total_timesteps  | 259316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 39828    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 264      |
# |    time_elapsed     | 985      |
# |    total_timesteps  | 260319   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00772  |
# |    n_updates        | 40079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 264      |
# |    time_elapsed     | 990      |
# |    total_timesteps  | 261457   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00861  |
# |    n_updates        | 40364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 264      |
# |    time_elapsed     | 992      |
# |    total_timesteps  | 262167   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 40541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 263      |
# |    time_elapsed     | 996      |
# |    total_timesteps  | 262881   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.076    |
# |    n_updates        | 40720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 263      |
# |    time_elapsed     | 1003     |
# |    total_timesteps  | 264509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 41127    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 263      |
# |    time_elapsed     | 1007     |
# |    total_timesteps  | 265428   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 41356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 263      |
# |    time_elapsed     | 1011     |
# |    total_timesteps  | 266207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 41551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 262      |
# |    time_elapsed     | 1014     |
# |    total_timesteps  | 266841   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00415  |
# |    n_updates        | 41710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 262      |
# |    time_elapsed     | 1018     |
# |    total_timesteps  | 267688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00707  |
# |    n_updates        | 41921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 262      |
# |    time_elapsed     | 1021     |
# |    total_timesteps  | 268499   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 42124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 262      |
# |    time_elapsed     | 1024     |
# |    total_timesteps  | 269214   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 42303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 262      |
# |    time_elapsed     | 1027     |
# |    total_timesteps  | 269871   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0084   |
# |    n_updates        | 42467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 262      |
# |    time_elapsed     | 1033     |
# |    total_timesteps  | 271048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 42761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 262      |
# |    time_elapsed     | 1036     |
# |    total_timesteps  | 271899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 42974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 262      |
# |    time_elapsed     | 1042     |
# |    total_timesteps  | 273132   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 43282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 261      |
# |    time_elapsed     | 1044     |
# |    total_timesteps  | 273578   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0386   |
# |    n_updates        | 43394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 261      |
# |    time_elapsed     | 1047     |
# |    total_timesteps  | 274240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0656   |
# |    n_updates        | 43559    |
# ----------------------------------
# Eval num_timesteps=275000, episode_reward=350.00 +/- 160.34
# Episode length: 3085.40 +/- 661.67
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.09e+03 |
# |    mean_reward      | 350      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 275000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00713  |
# |    n_updates        | 43749    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 259      |
# |    time_elapsed     | 1061     |
# |    total_timesteps  | 275137   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 43784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 259      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 276099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 44024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 259      |
# |    time_elapsed     | 1068     |
# |    total_timesteps  | 276786   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00964  |
# |    n_updates        | 44196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 259      |
# |    time_elapsed     | 1069     |
# |    total_timesteps  | 277197   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00961  |
# |    n_updates        | 44299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 258      |
# |    time_elapsed     | 1074     |
# |    total_timesteps  | 278069   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.034    |
# |    n_updates        | 44517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 258      |
# |    time_elapsed     | 1077     |
# |    total_timesteps  | 278715   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00599  |
# |    n_updates        | 44678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 258      |
# |    time_elapsed     | 1081     |
# |    total_timesteps  | 279557   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 44889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 258      |
# |    time_elapsed     | 1083     |
# |    total_timesteps  | 280184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 45045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 258      |
# |    time_elapsed     | 1086     |
# |    total_timesteps  | 280774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00922  |
# |    n_updates        | 45193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 258      |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 281644   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00697  |
# |    n_updates        | 45410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1484     |
# |    fps              | 258      |
# |    time_elapsed     | 1092     |
# |    total_timesteps  | 282173   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00615  |
# |    n_updates        | 45543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 258      |
# |    time_elapsed     | 1094     |
# |    total_timesteps  | 282527   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 45631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1492     |
# |    fps              | 258      |
# |    time_elapsed     | 1098     |
# |    total_timesteps  | 283462   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 45865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1496     |
# |    fps              | 258      |
# |    time_elapsed     | 1100     |
# |    total_timesteps  | 284003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 46000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 257      |
# |    time_elapsed     | 1104     |
# |    total_timesteps  | 284721   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 46180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 257      |
# |    time_elapsed     | 1108     |
# |    total_timesteps  | 285627   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00574  |
# |    n_updates        | 46406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 257      |
# |    time_elapsed     | 1112     |
# |    total_timesteps  | 286687   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 46671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 257      |
# |    time_elapsed     | 1114     |
# |    total_timesteps  | 287139   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00553  |
# |    n_updates        | 46784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 257      |
# |    time_elapsed     | 1118     |
# |    total_timesteps  | 287882   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00499  |
# |    n_updates        | 46970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 257      |
# |    time_elapsed     | 1121     |
# |    total_timesteps  | 288458   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00509  |
# |    n_updates        | 47114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.46e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 257      |
# |    time_elapsed     | 1126     |
# |    total_timesteps  | 289767   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 47441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.46e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 257      |
# |    time_elapsed     | 1128     |
# |    total_timesteps  | 290243   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 47560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.46e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 257      |
# |    time_elapsed     | 1131     |
# |    total_timesteps  | 290998   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 47749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 256      |
# |    time_elapsed     | 1134     |
# |    total_timesteps  | 291448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0916   |
# |    n_updates        | 47861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.43e+03 |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 256      |
# |    time_elapsed     | 1137     |
# |    total_timesteps  | 292067   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00702  |
# |    n_updates        | 48016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.43e+03 |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 256      |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 292763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 48190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 256      |
# |    time_elapsed     | 1142     |
# |    total_timesteps  | 293271   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0469   |
# |    n_updates        | 48317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 256      |
# |    time_elapsed     | 1146     |
# |    total_timesteps  | 294273   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 48568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 256      |
# |    time_elapsed     | 1148     |
# |    total_timesteps  | 294642   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0701   |
# |    n_updates        | 48660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 256      |
# |    time_elapsed     | 1151     |
# |    total_timesteps  | 295284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00853  |
# |    n_updates        | 48820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 256      |
# |    time_elapsed     | 1154     |
# |    total_timesteps  | 296112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00389  |
# |    n_updates        | 49027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 256      |
# |    time_elapsed     | 1157     |
# |    total_timesteps  | 296780   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 49194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 256      |
# |    time_elapsed     | 1160     |
# |    total_timesteps  | 297413   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0491   |
# |    n_updates        | 49353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 256      |
# |    time_elapsed     | 1164     |
# |    total_timesteps  | 298164   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 49540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 255      |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 298874   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 49718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 255      |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 299442   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0493   |
# |    n_updates        | 49860    |
# ----------------------------------
# Eval num_timesteps=300000, episode_reward=116.00 +/- 23.32
# Episode length: 1817.80 +/- 211.19
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.82e+03 |
# |    mean_reward      | 116      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 300000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00631  |
# |    n_updates        | 49999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 254      |
# |    time_elapsed     | 1181     |
# |    total_timesteps  | 300626   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00911  |
# |    n_updates        | 50156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 254      |
# |    time_elapsed     | 1183     |
# |    total_timesteps  | 301114   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00991  |
# |    n_updates        | 50278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 254      |
# |    time_elapsed     | 1186     |
# |    total_timesteps  | 301896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00992  |
# |    n_updates        | 50473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 254      |
# |    time_elapsed     | 1188     |
# |    total_timesteps  | 302466   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 50616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 254      |
# |    time_elapsed     | 1192     |
# |    total_timesteps  | 303141   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 50785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.33e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1608     |
# |    fps              | 254      |
# |    time_elapsed     | 1195     |
# |    total_timesteps  | 303721   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 50930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.33e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1612     |
# |    fps              | 253      |
# |    time_elapsed     | 1199     |
# |    total_timesteps  | 304379   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0982   |
# |    n_updates        | 51094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.32e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1616     |
# |    fps              | 253      |
# |    time_elapsed     | 1202     |
# |    total_timesteps  | 305077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0733   |
# |    n_updates        | 51269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 253      |
# |    time_elapsed     | 1204     |
# |    total_timesteps  | 305500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00653  |
# |    n_updates        | 51374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1624     |
# |    fps              | 253      |
# |    time_elapsed     | 1206     |
# |    total_timesteps  | 305964   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00796  |
# |    n_updates        | 51490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.27e+03 |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1628     |
# |    fps              | 253      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 306557   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 51639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.27e+03 |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1632     |
# |    fps              | 253      |
# |    time_elapsed     | 1212     |
# |    total_timesteps  | 307215   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 51803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1636     |
# |    fps              | 253      |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 308119   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00865  |
# |    n_updates        | 52029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 253      |
# |    time_elapsed     | 1219     |
# |    total_timesteps  | 308881   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00758  |
# |    n_updates        | 52220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1644     |
# |    fps              | 253      |
# |    time_elapsed     | 1225     |
# |    total_timesteps  | 310172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00891  |
# |    n_updates        | 52542    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1648     |
# |    fps              | 253      |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 310630   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 52657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1652     |
# |    fps              | 252      |
# |    time_elapsed     | 1230     |
# |    total_timesteps  | 311422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 52855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1656     |
# |    fps              | 252      |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 311978   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 52994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 252      |
# |    time_elapsed     | 1234     |
# |    total_timesteps  | 312413   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 53103    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1664     |
# |    fps              | 252      |
# |    time_elapsed     | 1238     |
# |    total_timesteps  | 313195   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00979  |
# |    n_updates        | 53298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# ...
# |    loss             | 0.0101   |
# |    n_updates        | 92897    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2492     |
# |    fps              | 236      |
# |    time_elapsed     | 2000     |
# |    total_timesteps  | 472561   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 93140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2496     |
# |    fps              | 236      |
# |    time_elapsed     | 2003     |
# |    total_timesteps  | 473379   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0325   |
# |    n_updates        | 93344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 236      |
# |    time_elapsed     | 2006     |
# |    total_timesteps  | 474023   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 93505    |
# ----------------------------------
# Eval num_timesteps=475000, episode_reward=368.00 +/- 137.03
# Episode length: 3307.00 +/- 707.08
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.31e+03 |
# |    mean_reward      | 368      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 475000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 93749    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 312      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2504     |
# |    fps              | 234      |
# |    time_elapsed     | 2023     |
# |    total_timesteps  | 475403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 93850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 318      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2508     |
# |    fps              | 234      |
# |    time_elapsed     | 2028     |
# |    total_timesteps  | 476490   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 94122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 320      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2512     |
# |    fps              | 234      |
# |    time_elapsed     | 2033     |
# |    total_timesteps  | 477506   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 94376    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.64e+03 |
# |    ep_rew_mean      | 326      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2516     |
# |    fps              | 234      |
# |    time_elapsed     | 2037     |
# |    total_timesteps  | 478619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0364   |
# |    n_updates        | 94654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.65e+03 |
# |    ep_rew_mean      | 328      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2520     |
# |    fps              | 234      |
# |    time_elapsed     | 2042     |
# |    total_timesteps  | 479695   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 94923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.71e+03 |
# |    ep_rew_mean      | 332      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2524     |
# |    fps              | 234      |
# |    time_elapsed     | 2051     |
# |    total_timesteps  | 481804   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 95450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+03  |
# |    ep_rew_mean      | 333      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2528     |
# |    fps              | 234      |
# |    time_elapsed     | 2054     |
# |    total_timesteps  | 482351   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0626   |
# |    n_updates        | 95587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+03  |
# |    ep_rew_mean      | 333      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2532     |
# |    fps              | 234      |
# |    time_elapsed     | 2058     |
# |    total_timesteps  | 482998   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 95749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.72e+03 |
# |    ep_rew_mean      | 336      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2536     |
# |    fps              | 234      |
# |    time_elapsed     | 2064     |
# |    total_timesteps  | 484150   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0528   |
# |    n_updates        | 96037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.72e+03 |
# |    ep_rew_mean      | 337      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2540     |
# |    fps              | 234      |
# |    time_elapsed     | 2068     |
# |    total_timesteps  | 485082   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 96270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.72e+03 |
# |    ep_rew_mean      | 337      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2544     |
# |    fps              | 234      |
# |    time_elapsed     | 2071     |
# |    total_timesteps  | 485846   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 96461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.74e+03 |
# |    ep_rew_mean      | 339      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2548     |
# |    fps              | 234      |
# |    time_elapsed     | 2078     |
# |    total_timesteps  | 487147   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0448   |
# |    n_updates        | 96786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75e+03 |
# |    ep_rew_mean      | 344      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2552     |
# |    fps              | 234      |
# |    time_elapsed     | 2082     |
# |    total_timesteps  | 488312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 97077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.78e+03 |
# |    ep_rew_mean      | 348      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2556     |
# |    fps              | 234      |
# |    time_elapsed     | 2085     |
# |    total_timesteps  | 488974   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 97243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.77e+03 |
# |    ep_rew_mean      | 347      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2560     |
# |    fps              | 234      |
# |    time_elapsed     | 2088     |
# |    total_timesteps  | 489720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 97429    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75e+03 |
# |    ep_rew_mean      | 346      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2564     |
# |    fps              | 234      |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 490564   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 97640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.78e+03 |
# |    ep_rew_mean      | 350      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2568     |
# |    fps              | 234      |
# |    time_elapsed     | 2097     |
# |    total_timesteps  | 491621   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 97905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.79e+03 |
# |    ep_rew_mean      | 351      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2572     |
# |    fps              | 234      |
# |    time_elapsed     | 2103     |
# |    total_timesteps  | 493022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0676   |
# |    n_updates        | 98255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.79e+03 |
# |    ep_rew_mean      | 353      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2576     |
# |    fps              | 234      |
# |    time_elapsed     | 2109     |
# |    total_timesteps  | 494118   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 98529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.78e+03 |
# |    ep_rew_mean      | 355      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2580     |
# |    fps              | 234      |
# |    time_elapsed     | 2112     |
# |    total_timesteps  | 494854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00924  |
# |    n_updates        | 98713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.78e+03 |
# |    ep_rew_mean      | 354      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2584     |
# |    fps              | 234      |
# |    time_elapsed     | 2115     |
# |    total_timesteps  | 495625   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 98906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.79e+03 |
# |    ep_rew_mean      | 358      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2588     |
# |    fps              | 234      |
# |    time_elapsed     | 2120     |
# |    total_timesteps  | 496712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 99177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.79e+03 |
# |    ep_rew_mean      | 356      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2592     |
# |    fps              | 234      |
# |    time_elapsed     | 2124     |
# |    total_timesteps  | 497501   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 99375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.79e+03 |
# |    ep_rew_mean      | 352      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2596     |
# |    fps              | 234      |
# |    time_elapsed     | 2128     |
# |    total_timesteps  | 498408   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 99601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.78e+03 |
# |    ep_rew_mean      | 352      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 234      |
# |    time_elapsed     | 2130     |
# |    total_timesteps  | 499026   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 99756    |
# ----------------------------------
# Eval num_timesteps=500000, episode_reward=494.00 +/- 131.35
# Episode length: 3225.80 +/- 541.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.23e+03 |
# |    mean_reward      | 494      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 500000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 99999    |
# ----------------------------------
# New best mean reward!
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2023-10-18 09:04:22.119459: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-18 09:04:23.479379: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 475.00
# Atari Episode Length 3027
# Atari Episode Score: 725.00
# Atari Episode Length 3725
# Atari Episode Score: 400.00
# Atari Episode Length 2561
# Atari Episode Score: 495.00
# Atari Episode Length 2341
# Atari Episode Score: 480.00
# Atari Episode Length 2639
# Atari Episode Score: 250.00
# Atari Episode Length 1711
# Atari Episode Score: 370.00
# Atari Episode Length 2977

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name SpaceInvaders-v4 -orga kowalsky -f logs/
# Out:
# 2023-10-18 09:05:29.944486: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-18 09:05:30.912428: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to kowalsky/SpaceInvaders-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Cloning https://huggingface.co/kowalsky/SpaceInvaders-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/kowalsky/SpaceInvaders-v4 into local empty directory.
# Saving model to: hub/SpaceInvaders-v4/dqn-SpaceInvadersNoFrameskip-v4
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /tmp/tmpzlws4m_d/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpzlws4m_d/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpzlws4m_d/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpzlws4m_d/-step-0-to-step-1000.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpzlws4m_d/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.40, start: 0.000000, bitrate: 60 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 57 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x598a5cf00ec0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x598a5cf00ec0] profile High, level 1.2, 4:2:0, 8-bit
# [libx264 @ 0x598a5cf00ec0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/SpaceInvaders-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 160x210, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1002 fps=0.0 q=-1.0 Lsize=     241kB time=00:00:33.30 bitrate=  59.3kbits/s speed=33.5x
# video:230kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.721370%
# [libx264 @ 0x598a5cf00ec0] frame I:5     Avg QP:17.40  size:  3637
# [libx264 @ 0x598a5cf00ec0] frame P:502   Avg QP:22.72  size:   383
# [libx264 @ 0x598a5cf00ec0] frame B:495   Avg QP:29.56  size:    50
# [libx264 @ 0x598a5cf00ec0] consecutive B-frames: 27.8% 15.6%  9.9% 46.7%
# [libx264 @ 0x598a5cf00ec0] mb I  I16..4: 26.7% 26.9% 46.4%
# [libx264 @ 0x598a5cf00ec0] mb P  I16..4:  0.4%  0.9%  0.9%  P16..4:  6.1%  3.0%  2.1%  0.0%  0.0%    skip:86.6%
# [libx264 @ 0x598a5cf00ec0] mb B  I16..4:  0.1%  0.1%  0.1%  B16..8:  9.1%  0.8%  0.1%  direct: 0.2%  skip:89.6%  L0:49.2% L1:50.3% BI: 0.5%
# [libx264 @ 0x598a5cf00ec0] 8x8 transform intra:37.3% inter:5.2%
# [libx264 @ 0x598a5cf00ec0] coded y,uvDC,uvAC intra: 25.4% 45.6% 42.3% inter: 1.6% 2.1% 1.8%
# [libx264 @ 0x598a5cf00ec0] i16 v,h,dc,p: 49% 43%  8%  0%
# [libx264 @ 0x598a5cf00ec0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25%  7% 67%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x598a5cf00ec0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 12% 40%  3%  2%  3%  1%  3%  2%
# [libx264 @ 0x598a5cf00ec0] i8c dc,h,v,p: 55% 28% 16%  1%
# [libx264 @ 0x598a5cf00ec0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x598a5cf00ec0] ref P L0: 75.9%  7.4%  9.0%  7.7%
# [libx264 @ 0x598a5cf00ec0] ref B L0: 83.7% 13.6%  2.7%
# [libx264 @ 0x598a5cf00ec0] ref B L1: 96.0%  4.0%
# [libx264 @ 0x598a5cf00ec0] kb/s:56.31
# ℹ Pushing repo SpaceInvaders-v4 to the Hugging Face Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 1.00/26.0M [00:00<?, ?B/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth:   0% 1.00/431 [00:00<?, ?B/s]
#
# Upload file train_eval_metrics.zip:   0% 1.00/22.6k [00:00<?, ?B/s]
#
#
# Upload file replay.mp4:   0% 1.00/241k [00:00<?, ?B/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 15.3MB [00:01, 16.0MB/s]
#
# Upload file train_eval_metrics.zip: 15.3MB [00:01, 16.0MB/s]
#
#
# Upload file replay.mp4: 15.3MB [00:02, 7.99MB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 15.3MB [00:02, 7.99MB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 30.5MB [00:03, 11.3MB/s]                To https://huggingface.co/kowalsky/SpaceInvaders-v4
#    93c4863..c2aa597  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/kowalsky/SpaceInvaders-v4
#    93c4863..c2aa597  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 26.0M/26.0M [00:04<00:00, 6.79MB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 431/431 [00:04<00:00, 107B/s]
#
#
# Upload file train_eval_metrics.zip: 100% 22.6k/22.6k [00:04<00:00, 5.76kB/s]
#
#
#
# Upload file replay.mp4: 100% 241k/241k [00:04<00:00, 61.6kB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:04<00:00, 3.37MB/s]
#
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:04<00:00, 3.37MB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/kowalsky/SpaceInvaders-v4
